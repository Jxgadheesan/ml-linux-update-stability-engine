# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect("../data/update_engine.db")
df = pd.read_sql("SELECT * FROM updates", conn)
df

# %%
df.plot(kind="bar", y="package_count", title="Package Count per Update")
plt.show()
